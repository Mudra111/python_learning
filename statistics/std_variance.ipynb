# %%
import numpy as np
# Out:
# Running cells with '.venv (Python 3.14.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/python_learning/statistics/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
arr = np.array([10, 12, 14, 16, 18])
